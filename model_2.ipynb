# %%
# Update sklearn to prevent version mismatches
#!pip install sklearn --upgrade

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
#!pip install joblib

# %%
import pandas as pd

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("Resources/exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
#selected_features = df[['names', 'of', 'selected', 'features', 'here']]

# selecting all features except our y-value
selected_features = df.drop("koi_disposition", axis=1)
selected_features
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 0                 0              0              0              0   54.418383
# 1                 0              1              0              0   19.899140
# 2                 0              1              0              0    1.736952
# 3                 0              0              0              0    2.525592
# 4                 0              0              0              0    4.134435
# ...             ...            ...            ...            ...         ...
# 6986              0              0              0              1    8.589871
# 6987              0              1              1              0    0.527699
# 6988              0              0              0              0    1.739849
# 6989              0              0              1              0    0.681402
# 6990              0              0              1              1    4.856035
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 0        2.479000e-04    -2.479000e-04   162.513840          0.003520
# 1        1.490000e-05    -1.490000e-05   175.850252          0.000581
# 2        2.630000e-07    -2.630000e-07   170.307565          0.000115
# 3        3.760000e-06    -3.760000e-06   171.595550          0.001130
# 4        1.050000e-05    -1.050000e-05   172.979370          0.001900
# ...               ...              ...          ...               ...
# 6986     1.846000e-04    -1.846000e-04   132.016100          0.015700
# 6987     1.160000e-07    -1.160000e-07   131.705093          0.000170
# 6988     1.780000e-05    -1.780000e-05   133.001270          0.007690
# 6989     2.430000e-06    -2.430000e-06   132.181750          0.002850
# 6990     6.360000e-05    -6.360000e-05   135.993300          0.010800
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0            -0.003520  ...             -81      4.467           0.064
# 1            -0.000581  ...            -176      4.544           0.044
# 2            -0.000115  ...            -174      4.564           0.053
# 3            -0.001130  ...            -211      4.438           0.070
# 4            -0.001900  ...            -232      4.486           0.054
# ...                ...  ...             ...        ...             ...
# 6986         -0.015700  ...            -152      4.296           0.231
# 6987         -0.000170  ...            -166      4.529           0.035
# 6988         -0.007690  ...            -220      4.444           0.056
# 6989         -0.002850  ...            -236      4.447           0.056
# 6990         -0.010800  ...            -225      4.385           0.054
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0             -0.096     0.927          0.105         -0.061  291.93423
# 1             -0.176     0.868          0.233         -0.078  297.00482
# 2             -0.168     0.791          0.201         -0.067  285.53461
# 3             -0.210     1.046          0.334         -0.133  288.75488
# 4             -0.229     0.972          0.315         -0.105  296.28613
# ...              ...       ...            ...            ...        ...
# 6986          -0.189     1.088          0.313         -0.228  298.74921
# 6987          -0.196     0.903          0.237         -0.079  297.18875
# 6988          -0.224     1.031          0.341         -0.114  286.50937
# 6989          -0.224     1.041          0.341         -0.114  294.16489
# 6990          -0.216     1.193          0.410         -0.137  297.00977
#
#             dec  koi_kepmag
# 0     48.141651      15.347
# 1     48.134129      15.436
# 2     48.285210      15.597
# 3     48.226200      15.509
# 4     48.224670      15.714
# ...         ...         ...
# 6986  46.973351      14.478
# 6987  47.093819      14.082
# 6988  47.163219      14.757
# 6989  47.176281      15.385
# 6990  47.121021      14.826
#
# [6991 rows x 40 columns]

# %%
# Out:
# (6991, 40) (6991,)

# %%
# Out:
# 0            CONFIRMED
# 1       FALSE_POSITIVE
# 2       FALSE_POSITIVE
# 3            CONFIRMED
# 4            CONFIRMED
#              ...
# 6986    FALSE_POSITIVE
# 6987    FALSE_POSITIVE
# 6988         CANDIDATE
# 6989    FALSE_POSITIVE
# 6990    FALSE_POSITIVE
# Name: koi_disposition, Length: 6991, dtype: object

# %%
# target = df["koi_disposition"]
# target_names = ["CONFIRMED", "FALSE_POSITIVE"]

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
# set our X and y 
X = selected_features
y = df['koi_disposition']
print(X.shape, y.shape)
# Out:
# (6991, 40) (6991,)

# %%
# format the FALSE POSITIVE value 
mask = df["koi_disposition"] == "FALSE POSITIVE"
df.loc[mask, "koi_disposition"] = "FALSE_POSITIVE"
df["koi_disposition"]
# Out:
# 0            CONFIRMED
# 1       FALSE_POSITIVE
# 2       FALSE_POSITIVE
# 3            CONFIRMED
# 4            CONFIRMED
#              ...
# 6986    FALSE_POSITIVE
# 6987    FALSE_POSITIVE
# 6988         CANDIDATE
# 6989    FALSE_POSITIVE
# 6990    FALSE_POSITIVE
# Name: koi_disposition, Length: 6991, dtype: object

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 6122              0              0              0              0    6.768901
# 6370              0              1              0              1    0.733726
# 2879              1              0              0              0    7.652707
# 107               0              0              0              0    7.953547
# 29                0              0              0              0    4.959319
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 6122     7.380000e-05    -7.380000e-05   133.077240          0.008440
# 6370     6.060000e-06    -6.060000e-06   132.020050          0.007950
# 2879     6.540000e-05    -6.540000e-05   134.460380          0.006190
# 107      1.910000e-05    -1.910000e-05   174.662240          0.001820
# 29       5.150000e-07    -5.150000e-07   172.258529          0.000083
#
#       koi_time0bk_err2  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 6122         -0.008440  ...            -171      4.327           0.153
# 6370         -0.007950  ...            -175      4.578           0.033
# 2879         -0.006190  ...            -189      4.481           0.050
# 107          -0.001820  ...             -85      4.536           0.056
# 29           -0.000083  ...             -77      4.359           0.110
#
#       koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 6122          -0.187     1.125          0.310         -0.207  294.40472
# 6370          -0.187     0.797          0.211         -0.056  284.50391
# 2879          -0.200     0.963          0.290         -0.097  295.50211
# 107           -0.016     0.779          0.023         -0.049  291.15878
# 29            -0.110     1.082          0.173         -0.130  292.16705
#
#             dec  koi_kepmag
# 6122  39.351681      14.725
# 6370  42.463860      15.770
# 2879  38.983540      13.099
# 107   40.750271      15.660
# 29    48.727589      15.263
#
# [5 rows x 40 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
from sklearn.preprocessing import LabelEncoder, MinMaxScaler, StandardScaler
from tensorflow.keras.utils import to_categorical

# %%
# MinMax Scaler 
X_scaler = MinMaxScaler().fit(X_train)
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# label encoding
label_encoder = LabelEncoder()
label_encoder.fit(y_train)
encoded_y_train = label_encoder.transform(y_train)
encoded_y_test = label_encoder.transform(y_test)
print(label_encoder.classes_)
encoded_y_train
# Out:
# ['CANDIDATE' 'CONFIRMED' 'FALSE_POSITIVE']
# array([0, 2, 2, ..., 2, 2, 2])

# %%
# to_categorical 
# y_train_categorical = to_categorical(encoded_y_train)
# print(y_train_categorical)
# y_train_categorical.dtype
# y_train_categorical.reshape(-1, 1)

# one-hot encoding
y_train_categorical = to_categorical(encoded_y_train)
y_test_categorical = to_categorical(encoded_y_test)

# %%
y_train_categorical.shape
# Out:
# (5243, 3)

# %% [markdown]
# ## Create Model Using Deep Learning

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense

# %%
# from sklearn.svm import SVC
# model = SVC(kernel='linear')
# model.fit(X_train, y_train)

# %%
# Create model and add layers
model = Sequential()
model.add(Dense(units=100, activation='relu', input_dim=40))
model.add(Dense(units=100, activation='relu'))
model.add(Dense(units=3, activation='softmax'))

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_14 (Dense)             (None, 100)               4100
# _________________________________________________________________
# dense_15 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_16 (Dense)             (None, 3)                 303
# =================================================================
# Total params: 14,503
# Trainable params: 14,503
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Fit the model to the training data
model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Train on 5243 samples
# Epoch 1/100
# 5243/5243 - 2s - loss: 0.5921 - accuracy: 0.7061
# Epoch 2/100
# 5243/5243 - 0s - loss: 0.3695 - accuracy: 0.8081
# Epoch 3/100
# 5243/5243 - 0s - loss: 0.3488 - accuracy: 0.8247
# Epoch 4/100
# 5243/5243 - 0s - loss: 0.3384 - accuracy: 0.8295
# Epoch 5/100
# 5243/5243 - 0s - loss: 0.3352 - accuracy: 0.8364
# Epoch 6/100
# 5243/5243 - 0s - loss: 0.3290 - accuracy: 0.8415
# Epoch 7/100
# 5243/5243 - 0s - loss: 0.3175 - accuracy: 0.8543
# Epoch 8/100
# 5243/5243 - 0s - loss: 0.3167 - accuracy: 0.8491
# Epoch 9/100
# 5243/5243 - 0s - loss: 0.3105 - accuracy: 0.8547
# Epoch 10/100
# 5243/5243 - 0s - loss: 0.3120 - accuracy: 0.8528
# Epoch 11/100
# 5243/5243 - 0s - loss: 0.3111 - accuracy: 0.8539
# Epoch 12/100
# 5243/5243 - 1s - loss: 0.2994 - accuracy: 0.8665
# Epoch 13/100
# 5243/5243 - 1s - loss: 0.2986 - accuracy: 0.8629
# Epoch 14/100
# 5243/5243 - 1s - loss: 0.2931 - accuracy: 0.8690
# Epoch 15/100
# 5243/5243 - 1s - loss: 0.2935 - accuracy: 0.8692
# Epoch 16/100
# 5243/5243 - 1s - loss: 0.2943 - accuracy: 0.8667
# Epoch 17/100
# 5243/5243 - 1s - loss: 0.2869 - accuracy: 0.8718
# Epoch 18/100
# 5243/5243 - 1s - loss: 0.2860 - accuracy: 0.8734
# Epoch 19/100
# 5243/5243 - 1s - loss: 0.2944 - accuracy: 0.8655
# Epoch 20/100
# 5243/5243 - 1s - loss: 0.2879 - accuracy: 0.8718
# Epoch 21/100
# 5243/5243 - 1s - loss: 0.2870 - accuracy: 0.8690
# Epoch 22/100
# 5243/5243 - 1s - loss: 0.2785 - accuracy: 0.8831
# Epoch 23/100
# 5243/5243 - 1s - loss: 0.2852 - accuracy: 0.8695
# Epoch 24/100
# 5243/5243 - 1s - loss: 0.2743 - accuracy: 0.8762
# Epoch 25/100
# 5243/5243 - 1s - loss: 0.2800 - accuracy: 0.8749
# Epoch 26/100
# 5243/5243 - 1s - loss: 0.2830 - accuracy: 0.8730
# Epoch 27/100
# 5243/5243 - 1s - loss: 0.2677 - accuracy: 0.8835
# Epoch 28/100
# 5243/5243 - 1s - loss: 0.2682 - accuracy: 0.8854
# Epoch 29/100
# 5243/5243 - 1s - loss: 0.2680 - accuracy: 0.8816
# Epoch 30/100
# 5243/5243 - 1s - loss: 0.2681 - accuracy: 0.8825
# Epoch 31/100
# 5243/5243 - 1s - loss: 0.2665 - accuracy: 0.8831
# Epoch 32/100
# 5243/5243 - 1s - loss: 0.2739 - accuracy: 0.8741
# Epoch 33/100
# 5243/5243 - 1s - loss: 0.2627 - accuracy: 0.8856
# Epoch 34/100
# 5243/5243 - 1s - loss: 0.2619 - accuracy: 0.8858
# Epoch 35/100
# 5243/5243 - 1s - loss: 0.2593 - accuracy: 0.8850
# Epoch 36/100
# 5243/5243 - 1s - loss: 0.2599 - accuracy: 0.8861
# Epoch 37/100
# 5243/5243 - 1s - loss: 0.2554 - accuracy: 0.8890
# Epoch 38/100
# 5243/5243 - 1s - loss: 0.2663 - accuracy: 0.8793
# Epoch 39/100
# 5243/5243 - 1s - loss: 0.2571 - accuracy: 0.8873
# Epoch 40/100
# 5243/5243 - 1s - loss: 0.2549 - accuracy: 0.8901
# Epoch 41/100
# 5243/5243 - 1s - loss: 0.2521 - accuracy: 0.8922
# Epoch 42/100
# 5243/5243 - 1s - loss: 0.2587 - accuracy: 0.8871
# Epoch 43/100
# 5243/5243 - 1s - loss: 0.2567 - accuracy: 0.8869
# Epoch 44/100
# 5243/5243 - 1s - loss: 0.2510 - accuracy: 0.8892
# Epoch 45/100
# 5243/5243 - 1s - loss: 0.2504 - accuracy: 0.8877
# Epoch 46/100
# 5243/5243 - 1s - loss: 0.2531 - accuracy: 0.8877
# Epoch 47/100
# 5243/5243 - 1s - loss: 0.2526 - accuracy: 0.8880
# Epoch 48/100
# 5243/5243 - 1s - loss: 0.2466 - accuracy: 0.8894
# Epoch 49/100
# 5243/5243 - 1s - loss: 0.2437 - accuracy: 0.8938
# Epoch 50/100
# 5243/5243 - 1s - loss: 0.2454 - accuracy: 0.8905
# Epoch 51/100
# 5243/5243 - 1s - loss: 0.2528 - accuracy: 0.8890
# Epoch 52/100
# 5243/5243 - 1s - loss: 0.2457 - accuracy: 0.8919
# Epoch 53/100
# 5243/5243 - 1s - loss: 0.2423 - accuracy: 0.8936
# Epoch 54/100
# 5243/5243 - 1s - loss: 0.2431 - accuracy: 0.8926
# Epoch 55/100
# 5243/5243 - 1s - loss: 0.2373 - accuracy: 0.8951
# Epoch 56/100
# 5243/5243 - 1s - loss: 0.2414 - accuracy: 0.8919
# Epoch 57/100
# 5243/5243 - 1s - loss: 0.2353 - accuracy: 0.8964
# Epoch 58/100
# 5243/5243 - 1s - loss: 0.2341 - accuracy: 0.8955
# Epoch 59/100
# 5243/5243 - 1s - loss: 0.2396 - accuracy: 0.8930
# Epoch 60/100
# 5243/5243 - 1s - loss: 0.2391 - accuracy: 0.8928
# Epoch 61/100
# 5243/5243 - 1s - loss: 0.2328 - accuracy: 0.8985
# Epoch 62/100
# 5243/5243 - 1s - loss: 0.2401 - accuracy: 0.8911
# Epoch 63/100
# 5243/5243 - 1s - loss: 0.2345 - accuracy: 0.8945
# Epoch 64/100
# 5243/5243 - 1s - loss: 0.2340 - accuracy: 0.8976
# Epoch 65/100
# 5243/5243 - 1s - loss: 0.2375 - accuracy: 0.8949
# Epoch 66/100
# 5243/5243 - 1s - loss: 0.2349 - accuracy: 0.8957
# Epoch 67/100
# 5243/5243 - 1s - loss: 0.2405 - accuracy: 0.8909
# Epoch 68/100
# 5243/5243 - 1s - loss: 0.2296 - accuracy: 0.8993
# Epoch 69/100
# 5243/5243 - 1s - loss: 0.2321 - accuracy: 0.8991
# Epoch 70/100
# 5243/5243 - 1s - loss: 0.2290 - accuracy: 0.8995
# Epoch 71/100
# 5243/5243 - 1s - loss: 0.2316 - accuracy: 0.8943
# Epoch 72/100
# 5243/5243 - 1s - loss: 0.2242 - accuracy: 0.9037
# Epoch 73/100
# 5243/5243 - 1s - loss: 0.2332 - accuracy: 0.8983
# Epoch 74/100
# 5243/5243 - 1s - loss: 0.2331 - accuracy: 0.8920
# Epoch 75/100
# 5243/5243 - 1s - loss: 0.2258 - accuracy: 0.9006
# Epoch 76/100
# 5243/5243 - 1s - loss: 0.2229 - accuracy: 0.8989
# Epoch 77/100
# 5243/5243 - 1s - loss: 0.2280 - accuracy: 0.8993
# Epoch 78/100
# 5243/5243 - 1s - loss: 0.2317 - accuracy: 0.8991
# Epoch 79/100
# 5243/5243 - 1s - loss: 0.2268 - accuracy: 0.8989
# Epoch 80/100
# 5243/5243 - 1s - loss: 0.2195 - accuracy: 0.8991
# Epoch 81/100
# 5243/5243 - 1s - loss: 0.2266 - accuracy: 0.8999
# Epoch 82/100
# 5243/5243 - 1s - loss: 0.2245 - accuracy: 0.8981
# Epoch 83/100
# 5243/5243 - 1s - loss: 0.2202 - accuracy: 0.9006
# Epoch 84/100
# 5243/5243 - 1s - loss: 0.2250 - accuracy: 0.9018
# Epoch 85/100
# 5243/5243 - 1s - loss: 0.2227 - accuracy: 0.9022
# Epoch 86/100
# 5243/5243 - 1s - loss: 0.2249 - accuracy: 0.9022
# Epoch 87/100
# 5243/5243 - 1s - loss: 0.2199 - accuracy: 0.9001
# Epoch 88/100
# 5243/5243 - 1s - loss: 0.2239 - accuracy: 0.8999
# Epoch 89/100
# 5243/5243 - 1s - loss: 0.2246 - accuracy: 0.8995
# Epoch 90/100
# 5243/5243 - 1s - loss: 0.2177 - accuracy: 0.9027
# Epoch 91/100
# 5243/5243 - 1s - loss: 0.2253 - accuracy: 0.9023
# Epoch 92/100
# 5243/5243 - 1s - loss: 0.2208 - accuracy: 0.8999
# Epoch 93/100
# 5243/5243 - 1s - loss: 0.2172 - accuracy: 0.9037
# Epoch 94/100
# 5243/5243 - 1s - loss: 0.2217 - accuracy: 0.8985
# Epoch 95/100
# 5243/5243 - 1s - loss: 0.2236 - accuracy: 0.8993
# Epoch 96/100
# 5243/5243 - 1s - loss: 0.2141 - accuracy: 0.9086
# Epoch 97/100
# 5243/5243 - 1s - loss: 0.2177 - accuracy: 0.9001
# Epoch 98/100
# 5243/5243 - 1s - loss: 0.2191 - accuracy: 0.9031
# Epoch 99/100
# 5243/5243 - 1s - loss: 0.2126 - accuracy: 0.9065
# Epoch 100/100
# 5243/5243 - 1s - loss: 0.2125 - accuracy: 0.9067

# %%
# add an additional layer of 100 nodes
deep_model = Sequential()
deep_model.add(Dense(units=100, activation='relu', input_dim=40))
deep_model.add(Dense(units=100, activation='relu'))
deep_model.add(Dense(units=100, activation='relu'))
deep_model.add(Dense(units=3, activation='softmax'))

# %%
deep_model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_17 (Dense)             (None, 100)               4100
# _________________________________________________________________
# dense_18 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_19 (Dense)             (None, 100)               10100
# _________________________________________________________________
# dense_20 (Dense)             (None, 3)                 303
# =================================================================
# Total params: 24,603
# Trainable params: 24,603
# Non-trainable params: 0
# _________________________________________________________________

# %%
deep_model.compile(optimizer='adam',
                   loss='categorical_crossentropy',
                   metrics=['accuracy'])

deep_model.fit(
    X_train_scaled,
    y_train_categorical,
    epochs=100,
    shuffle=True,
    verbose=2
)
# Out:
# Train on 5243 samples
# Epoch 1/100
# 5243/5243 - 1s - loss: 0.4807 - accuracy: 0.7625
# Epoch 2/100
# 5243/5243 - 1s - loss: 0.3518 - accuracy: 0.8184
# Epoch 3/100
# 5243/5243 - 1s - loss: 0.3439 - accuracy: 0.8255
# Epoch 4/100
# 5243/5243 - 1s - loss: 0.3307 - accuracy: 0.8446
# Epoch 5/100
# 5243/5243 - 1s - loss: 0.3275 - accuracy: 0.8432
# Epoch 6/100
# 5243/5243 - 1s - loss: 0.3169 - accuracy: 0.8488
# Epoch 7/100
# 5243/5243 - 1s - loss: 0.3150 - accuracy: 0.8575
# Epoch 8/100
# 5243/5243 - 1s - loss: 0.3033 - accuracy: 0.8602
# Epoch 9/100
# 5243/5243 - 1s - loss: 0.3052 - accuracy: 0.8577
# Epoch 10/100
# 5243/5243 - 1s - loss: 0.3048 - accuracy: 0.8594
# Epoch 11/100
# 5243/5243 - 1s - loss: 0.2949 - accuracy: 0.8674
# Epoch 12/100
# 5243/5243 - 1s - loss: 0.2977 - accuracy: 0.8671
# Epoch 13/100
# 5243/5243 - 1s - loss: 0.2898 - accuracy: 0.8737
# Epoch 14/100
# 5243/5243 - 1s - loss: 0.2848 - accuracy: 0.8737
# Epoch 15/100
# 5243/5243 - 1s - loss: 0.2832 - accuracy: 0.8739
# Epoch 16/100
# 5243/5243 - 1s - loss: 0.2861 - accuracy: 0.8724
# Epoch 17/100
# 5243/5243 - 1s - loss: 0.2735 - accuracy: 0.8796
# Epoch 18/100
# 5243/5243 - 1s - loss: 0.2726 - accuracy: 0.8741
# Epoch 19/100
# 5243/5243 - 1s - loss: 0.2703 - accuracy: 0.8812
# Epoch 20/100
# 5243/5243 - 1s - loss: 0.2721 - accuracy: 0.8762
# Epoch 21/100
# 5243/5243 - 1s - loss: 0.2729 - accuracy: 0.8806
# Epoch 22/100
# 5243/5243 - 1s - loss: 0.2643 - accuracy: 0.8844
# Epoch 23/100
# 5243/5243 - 1s - loss: 0.2728 - accuracy: 0.8774
# Epoch 24/100
# 5243/5243 - 1s - loss: 0.2705 - accuracy: 0.8783
# Epoch 25/100
# 5243/5243 - 1s - loss: 0.2640 - accuracy: 0.8856
# Epoch 26/100
# 5243/5243 - 1s - loss: 0.2639 - accuracy: 0.8825
# Epoch 27/100
# 5243/5243 - 1s - loss: 0.2659 - accuracy: 0.8823
# Epoch 28/100
# 5243/5243 - 1s - loss: 0.2612 - accuracy: 0.8829
# Epoch 29/100
# 5243/5243 - 1s - loss: 0.2590 - accuracy: 0.8848
# Epoch 30/100
# 5243/5243 - 1s - loss: 0.2673 - accuracy: 0.8802
# Epoch 31/100
# 5243/5243 - 1s - loss: 0.2536 - accuracy: 0.8890
# Epoch 32/100
# 5243/5243 - 1s - loss: 0.2525 - accuracy: 0.8924
# Epoch 33/100
# 5243/5243 - 1s - loss: 0.2603 - accuracy: 0.8867
# Epoch 34/100
# 5243/5243 - 1s - loss: 0.2599 - accuracy: 0.8831
# Epoch 35/100
# 5243/5243 - 1s - loss: 0.2497 - accuracy: 0.8905
# Epoch 36/100
# 5243/5243 - 1s - loss: 0.2520 - accuracy: 0.8875
# Epoch 37/100
# 5243/5243 - 1s - loss: 0.2543 - accuracy: 0.8884
# Epoch 38/100
# 5243/5243 - 1s - loss: 0.2534 - accuracy: 0.8892
# Epoch 39/100
# 5243/5243 - 1s - loss: 0.2491 - accuracy: 0.8919
# Epoch 40/100
# 5243/5243 - 1s - loss: 0.2446 - accuracy: 0.8913
# Epoch 41/100
# 5243/5243 - 1s - loss: 0.2450 - accuracy: 0.8919
# Epoch 42/100
# 5243/5243 - 1s - loss: 0.2410 - accuracy: 0.8920
# Epoch 43/100
# 5243/5243 - 1s - loss: 0.2486 - accuracy: 0.8894
# Epoch 44/100
# 5243/5243 - 1s - loss: 0.2418 - accuracy: 0.8917
# Epoch 45/100
# 5243/5243 - 1s - loss: 0.2427 - accuracy: 0.8945
# Epoch 46/100
# 5243/5243 - 1s - loss: 0.2475 - accuracy: 0.8890
# Epoch 47/100
# 5243/5243 - 1s - loss: 0.2342 - accuracy: 0.8945
# Epoch 48/100
# 5243/5243 - 1s - loss: 0.2405 - accuracy: 0.8919
# Epoch 49/100
# 5243/5243 - 1s - loss: 0.2428 - accuracy: 0.8940
# Epoch 50/100
# 5243/5243 - 1s - loss: 0.2413 - accuracy: 0.8945
# Epoch 51/100
# 5243/5243 - 1s - loss: 0.2382 - accuracy: 0.8953
# Epoch 52/100
# 5243/5243 - 1s - loss: 0.2391 - accuracy: 0.8934
# Epoch 53/100
# 5243/5243 - 1s - loss: 0.2360 - accuracy: 0.8924
# Epoch 54/100
# 5243/5243 - 1s - loss: 0.2427 - accuracy: 0.8905
# Epoch 55/100
# 5243/5243 - 1s - loss: 0.2384 - accuracy: 0.8945
# Epoch 56/100
# 5243/5243 - 1s - loss: 0.2375 - accuracy: 0.8974
# Epoch 57/100
# 5243/5243 - 1s - loss: 0.2307 - accuracy: 0.8978
# Epoch 58/100
# 5243/5243 - 1s - loss: 0.2362 - accuracy: 0.8961
# Epoch 59/100
# 5243/5243 - 1s - loss: 0.2323 - accuracy: 0.8981
# Epoch 60/100
# 5243/5243 - 1s - loss: 0.2339 - accuracy: 0.8995
# Epoch 61/100
# 5243/5243 - 1s - loss: 0.2310 - accuracy: 0.8964
# Epoch 62/100
# 5243/5243 - 1s - loss: 0.2360 - accuracy: 0.8947
# Epoch 63/100
# 5243/5243 - 1s - loss: 0.2323 - accuracy: 0.8964
# Epoch 64/100
# 5243/5243 - 1s - loss: 0.2328 - accuracy: 0.8943
# Epoch 65/100
# 5243/5243 - 1s - loss: 0.2223 - accuracy: 0.9044
# Epoch 66/100
# 5243/5243 - 1s - loss: 0.2239 - accuracy: 0.8997
# Epoch 67/100
# 5243/5243 - 1s - loss: 0.2271 - accuracy: 0.9016
# Epoch 68/100
# 5243/5243 - 1s - loss: 0.2231 - accuracy: 0.9004
# Epoch 69/100
# 5243/5243 - 1s - loss: 0.2291 - accuracy: 0.8978
# Epoch 70/100
# 5243/5243 - 1s - loss: 0.2220 - accuracy: 0.8999
# Epoch 71/100
# 5243/5243 - 1s - loss: 0.2290 - accuracy: 0.8968
# Epoch 72/100
# 5243/5243 - 1s - loss: 0.2223 - accuracy: 0.9006
# Epoch 73/100
# 5243/5243 - 1s - loss: 0.2187 - accuracy: 0.8989
# Epoch 74/100
# 5243/5243 - 1s - loss: 0.2257 - accuracy: 0.9008
# Epoch 75/100
# 5243/5243 - 1s - loss: 0.2192 - accuracy: 0.9010
# Epoch 76/100
# 5243/5243 - 1s - loss: 0.2242 - accuracy: 0.8999
# Epoch 77/100
# 5243/5243 - 1s - loss: 0.2274 - accuracy: 0.8978
# Epoch 78/100
# 5243/5243 - 1s - loss: 0.2132 - accuracy: 0.9044
# Epoch 79/100
# 5243/5243 - 1s - loss: 0.2137 - accuracy: 0.9065
# Epoch 80/100
# 5243/5243 - 1s - loss: 0.2155 - accuracy: 0.9037
# Epoch 81/100
# 5243/5243 - 1s - loss: 0.2191 - accuracy: 0.9033
# Epoch 82/100
# 5243/5243 - 1s - loss: 0.2242 - accuracy: 0.8951
# Epoch 83/100
# 5243/5243 - 1s - loss: 0.2122 - accuracy: 0.9046
# Epoch 84/100
# 5243/5243 - 1s - loss: 0.2155 - accuracy: 0.9029
# Epoch 85/100
# 5243/5243 - 1s - loss: 0.2092 - accuracy: 0.9075
# Epoch 86/100
# 5243/5243 - 1s - loss: 0.2112 - accuracy: 0.9064
# Epoch 87/100
# 5243/5243 - 1s - loss: 0.2115 - accuracy: 0.9020
# Epoch 88/100
# 5243/5243 - 1s - loss: 0.2190 - accuracy: 0.8991
# Epoch 89/100
# 5243/5243 - 1s - loss: 0.2116 - accuracy: 0.9050
# Epoch 90/100
# 5243/5243 - 1s - loss: 0.2104 - accuracy: 0.9041
# Epoch 91/100
# 5243/5243 - 1s - loss: 0.2146 - accuracy: 0.9058
# Epoch 92/100
# 5243/5243 - 1s - loss: 0.2185 - accuracy: 0.8972
# Epoch 93/100
# 5243/5243 - 1s - loss: 0.2040 - accuracy: 0.9084
# Epoch 94/100
# 5243/5243 - 1s - loss: 0.2118 - accuracy: 0.9025
# Epoch 95/100
# 5243/5243 - 1s - loss: 0.2076 - accuracy: 0.9056
# Epoch 96/100
# 5243/5243 - 1s - loss: 0.2138 - accuracy: 0.9041
# Epoch 97/100
# 5243/5243 - 1s - loss: 0.2092 - accuracy: 0.9084
# Epoch 98/100
# 5243/5243 - 1s - loss: 0.2037 - accuracy: 0.9111
# Epoch 99/100
# 5243/5243 - 1s - loss: 0.2051 - accuracy: 0.9102
# Epoch 100/100
# 5243/5243 - 1s - loss: 0.2100 - accuracy: 0.9056

# %% [markdown]
# # Train the Model

# %%
print(f"Training Data Score: {model2.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {model2.score(X_test_scaled, y_test)}")

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model

# %%
# Train the model with GridSearch

# %%
print(grid2.best_params_)
print(grid2.best_score_)

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'your_name.sav'
joblib.dump(your_model, filename)
